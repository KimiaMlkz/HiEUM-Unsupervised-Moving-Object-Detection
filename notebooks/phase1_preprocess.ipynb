# %% [markdown]
# Checking versions

# %%
import sys
import platform

print("Python version:", sys.version)
print("Platform:", platform.platform())
# Out:
# Python version: 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]
# Platform: Windows-11-10.0.26100-SP0

# %% [markdown]
# Installing the required libraries

# %%
# !pip install numpy scipy opencv-python matplotlib scikit-image tqdm
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cpu
# Out:
# ...
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...

# %% [markdown]
# PyTorch review and CPU tuning

# %%
import torch

device = torch.device("cpu")
print("Torch version:", torch.__version__)
print("Using device:", device)
# Out:
# Torch version: 2.10.0+cpu
# Using device: cpu

# %% [markdown]
# HiEUM project folder structure

# %%
import os

folders = [
    "HiEUM_Project/data/car",
    "HiEUM_Project/src",
    "HiEUM_Project/outputs",
    "HiEUM_Project/notebooks"
]

for f in folders:
    os.makedirs(f, exist_ok=True)

print("Project folders created.")
# Out:
# Project folders created.

# %% [markdown]
# Dataset access test

# %%
import json

ann_path = "C:/Users/KimiaMalekizadeh/Downloads/VISO/coco/car/Annotations/instances_train2017_small.json"

with open(ann_path, "r") as f:
    coco_data = json.load(f)

print("Keys:", coco_data.keys())
print("Number of images:", len(coco_data["images"]))
print("Number of annotations:", len(coco_data["annotations"]))
# Out:
# Keys: dict_keys(['images', 'annotations', 'categories'])
# Number of images: 50
# Number of annotations: 3267
